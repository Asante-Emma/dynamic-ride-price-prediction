# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# %%
df = pd.read_csv("../data/processed/processed_1.csv")
df.sample(2)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 10                 86                 17             Urban
# 456                85                 37             Rural
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 10                  Regular                    99             4.69
# 456                    Gold                    10             3.76
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 10          Morning      Economy                     167
# 456           Night      Premium                      61
#
#      Historical_Cost_of_Ride  Adjusted_Cost      Profit  Profit_Percentage
# 10                669.298626     906.341748  237.043122          35.416645
# 456               309.082545     293.696168  -15.386376          -4.978080

# %%
def preprocess_data(data):
  """
  Preprocesses data for use in the dynamic pricing model

  Args:
      data: A pandas DataFrame containing the ride data

  Returns:
      A preprocessed pandas DataFrame
  """
  # Identify numeric and categorical features
  numeric_features = data.select_dtypes(include=['float', 'int']).columns
  categorical_features = data.select_dtypes(include=['object']).columns

  # Handle missing values in numeric features
  data[numeric_features] = data[numeric_features].fillna(data[numeric_features].median())

  # Handle outliers in numeric features
  for feature in numeric_features:
    q1 = data[feature].quantile(0.25)
    q3 = data[feature].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    data[feature] = np.clip(data[feature], lower_bound, upper_bound)

  # Handle missing values in categorical features (consider alternative methods)
  data[categorical_features] = data[categorical_features].fillna(data[categorical_features].mode().iloc[0])

  return data

# %%
processed_df = preprocess_data(df)
processed_df.head(20)
# Out:
#     Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                 90               45.0             Urban
# 1                 58               39.0          Suburban
# 2                 42               31.0             Rural
# 3                 89               28.0             Rural
# 4                 78               22.0             Rural
# 5                 59               35.0             Urban
# 6                 93               43.0          Suburban
# 7                 62               39.0             Rural
# 8                 79               14.0             Rural
# 9                 42                6.0             Rural
# 10                86               17.0             Urban
# 11                60               38.0             Rural
# 12                24                8.0             Rural
# 13                36               24.0          Suburban
# 14                63               13.0             Rural
# 15                39               12.0             Urban
# 16                38               28.0             Rural
# 17                46               14.0          Suburban
# 18                33                7.0          Suburban
# 19                31                7.0          Suburban
#
#    Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                   Silver                    13             4.47
# 1                   Silver                    72             4.06
# 2                   Silver                     0             3.99
# 3                  Regular                    67             4.31
# 4                  Regular                    74             3.77
# 5                   Silver                    83             3.51
# 6                  Regular                    44             4.41
# 7                     Gold                    83             3.59
# 8                   Silver                    71             3.74
# 9                   Silver                    21             3.85
# 10                 Regular                    99             4.69
# 11                    Gold                    15             4.14
# 12                    Gold                    50             4.12
# 13                  Silver                    88             4.22
# 14                 Regular                    74             4.95
# 15                  Silver                    30             4.51
# 16                  Silver                    35             3.93
# 17                  Silver                    21             4.71
# 18                    Gold                    49             4.31
# 19                  Silver                    24             4.82
#
#    Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0            Night      Premium                      90
# 1          Evening      Economy                      43
# 2        Afternoon      Premium                      76
# 3        Afternoon      Premium                     134
# 4        Afternoon      Economy                     149
# 5            Night      Economy                     128
# 6        Afternoon      Premium                      16
# 7        Afternoon      Premium                      47
# 8          Evening      Economy                     128
# 9            Night      Premium                     128
# 10         Morning      Economy                     167
# 11         Evening      Premium                     144
# 12         Morning      Economy                     164
# 13           Night      Premium                      83
# 14       Afternoon      Premium                     102
# 15       Afternoon      Premium                     140
# 16       Afternoon      Premium                      54
# 17       Afternoon      Economy                      15
# 18         Evening      Premium                      22
# 19         Evening      Premium                      87
#
#     Historical_Cost_of_Ride  Adjusted_Cost      Profit  Profit_Percentage
# 0                284.257273     270.971017  -13.286256          -4.674025
# 1                173.874753     157.709039  -16.165714          -9.297332
# 2                329.795469     327.065489   -2.729980          -0.827780
# 3                470.201232     516.434717   46.233485           9.832702
# 4                579.681422     702.202113  122.520690          21.135866
# 5                339.955361     323.592044  -16.363316          -4.813372
# 6                104.061541      98.984861   -5.076680          -4.878536
# 7                235.811864     214.874302  -20.937562          -8.878926
# 8                501.412517     722.839391  221.426873          44.160619
# 9                398.993365     693.838273  294.844908          73.897196
# 10               669.298626     906.341748  237.043122          35.416645
# 11               414.990105     378.531005  -36.459099          -8.785535
# 12               490.410722     778.269458  287.858736          58.697480
# 13               296.242876     328.758055   32.515179          10.975852
# 14               327.088865     475.138852  148.049987          45.262925
# 15               445.136868     644.124471  198.987603          44.702566
# 16               244.536172     253.479935    8.943763           3.657440
# 17                47.314309      65.699415   18.385106          38.857392
# 18               129.808263     215.542577   85.734314          66.046885
# 19               382.948110     634.063228  251.115118          65.574189

# %%
processed_df.to_csv("../data/processed/processed_final.csv", index=False)
